# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\stockdata.csv')
df
# Out:
#   tickers            eps  rev price         people
# 0   GOOGL          27.82   87   845     Larry Page
# 1     WMT           4.61  484    65           n.a.
# 2    MSFT             -1   85    64     Bill Gates
# 3     RIL  not available   50  1023  Mukesh Ambani
# 4    TATA            5.6   -1  n.a.     Ratan Tata

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\stockdata.csv',
    na_values= ['not available','n.a.'])
df
# Out:
#   tickers    eps  rev   price         people
# 0   GOOGL  27.82   87   845.0     Larry Page
# 1     WMT   4.61  484    65.0            NaN
# 2    MSFT  -1.00   85    64.0     Bill Gates
# 3     RIL    NaN   50  1023.0  Mukesh Ambani
# 4    TATA   5.60   -1     NaN     Ratan Tata

# %%
df
# Out:
#   tickers    eps  rev   price         people
# 0   GOOGL  27.82   87   845.0     Larry Page
# 1     WMT   4.61  484    65.0            NaN
# 2    MSFT  -1.00   85    64.0     Bill Gates
# 3     RIL    NaN   50  1023.0  Mukesh Ambani
# 4    TATA   5.60   -1     NaN     Ratan Tata

# %%
df.to_csv('C:\\MyData\\Python\\DataSet\\newewrite.csv',index=False)

# %%
df.to_csv('C:\\MyData\\Python\\DataSet\\newewrite.csv',columns=['tickers','people'])

# %%
df=pd.read_excel('C:\\MyData\\Python\\DataSet\\stockex.xlsx',sheet_name='Stock')
df
# Out:
#   tickers            eps  rev price         people
# 0   GOOGL          27.82   87   845     Larry Page
# 1     WMT           4.61  484    65           n.a.
# 2    MSFT             -1   85    64     Bill Gates
# 3     RIL  not available   50  1023  Mukesh Ambani
# 4    TATA            5.6   -1  n.a.     Ratan Tata

# %%
def convert_people_cell(cell):
    if cell=='n.a.':
        return 'sam walton'
    return cell
df=pd.read_excel('C:\\MyData\\Python\\DataSet\\stockex.xlsx','Stock',converters={
    'people':convert_people_cell
})
df
# Out:
#   tickers            eps  rev price         people
# 0   GOOGL          27.82   87   845     Larry Page
# 1     WMT           4.61  484    65     sam walton
# 2    MSFT             -1   85    64     Bill Gates
# 3     RIL  not available   50  1023  Mukesh Ambani
# 4    TATA            5.6   -1  n.a.     Ratan Tata

# %%
df_stocks=pd.DataFrame({
    'tickers':['GOOGL','WMT','MSFT'],
    'price':[845,65,64],
    'pe':[30.37,14.26,30.97],
    'eps':[27.82,4.61,2.12]
})
df_stocks
# Out:
#   tickers  price     pe    eps
# 0   GOOGL    845  30.37  27.82
# 1     WMT     65  14.26   4.61
# 2    MSFT     64  30.97   2.12

# %%
df_Weather=pd.DataFrame({
    'day':['1/1/2017','1/2/2017','1/3/2017'],
    'temp':[32,35,28],
    'event':['Rain','Sunny','Snow']
})
df_Weather
# Out:
#         day  temp  event
# 0  1/1/2017    32   Rain
# 1  1/2/2017    35  Sunny
# 2  1/3/2017    28   Snow

# %%
with pd.ExcelWriter('C:\\MyData\\Python\\DataSet\\twoframe.xlsx') as writer:
    df_stocks.to_excel(writer,sheet_name='stock')
    df_Weather.to_excel(writer,sheet_name='weather')

# %%
weather_data={
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temp':[32,35,28,24,32,31],
    'wind':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']
}
df=pd.DataFrame(weather_data)
df
# Out:
#         day  temp  wind  event
# 0  1/1/2017    32     6   Rain
# 1  1/2/2017    35     7  Sunny
# 2  1/3/2017    28     2   Snow
# 3  1/4/2017    24     7   Snow
# 4  1/5/2017    32     4   Rain
# 5  1/6/2017    31     2  Sunny

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\weather_data.csv')

# %%
df
# Out:
#    Unnamed: 0         day  temp  wind   event
# 0           0  01-01-2017  32.0   6.0    Rain
# 1           1  01-04-2017   NaN   9.0   Sunny
# 2           2  01-05-2017  28.0   NaN    Snow
# 3           3  01-06-2017   NaN   7.0     NaN
# 4           4  01-07-2017  32.0   NaN    Rain
# 5           5  01-08-2017   NaN   NaN   Sunny
# 6           6  01-09-2017   NaN   NaN     NaN
# 7           7  01-10-2017  34.0   8.0  Cloudy
# 8           8  01-11-2017  40.0  12.0   Sunny

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\weather_data.csv',parse_dates=['day'])
df
# Out:
#          day  temp  wind   event
# 0 2017-01-01  32.0   6.0    Rain
# 1 2017-01-04   NaN   9.0   Sunny
# 2 2017-01-05  28.0   NaN    Snow
# 3 2017-01-06   NaN   7.0     NaN
# 4 2017-01-07  32.0   NaN    Rain
# 5 2017-01-08   NaN   NaN   Sunny
# 6 2017-01-09   NaN   NaN     NaN
# 7 2017-01-10  34.0   8.0  Cloudy
# 8 2017-01-11  40.0  12.0   Sunny

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
new_df=df.fillna(0)
new_df
# Out:
#             temp  wind   event
# day
# 2017-01-01  32.0   6.0    Rain
# 2017-01-04   0.0   9.0   Sunny
# 2017-01-05  28.0   0.0    Snow
# 2017-01-06   0.0   7.0       0
# 2017-01-07  32.0   0.0    Rain
# 2017-01-08   0.0   0.0   Sunny
# 2017-01-09   0.0   0.0       0
# 2017-01-10  34.0   8.0  Cloudy
# 2017-01-11  40.0  12.0   Sunny

# %%
new_df.columns
# Out:
# Index(['temp', 'wind', 'event'], dtype='object')

# %%
new_df=df.fillna({
    'temp':0,
    'wind':0,
    'event':'No Event'
})
new_df
# Out:
#             temp  wind     event
# day
# 2017-01-01  32.0   6.0      Rain
# 2017-01-04   0.0   9.0     Sunny
# 2017-01-05  28.0   0.0      Snow
# 2017-01-06   0.0   7.0  No Event
# 2017-01-07  32.0   0.0      Rain
# 2017-01-08   0.0   0.0     Sunny
# 2017-01-09   0.0   0.0  No Event
# 2017-01-10  34.0   8.0    Cloudy
# 2017-01-11  40.0  12.0     Sunny

# %%
new_df=df.fillna(method='ffill')
new_df
# Out:
#             temp  wind   event
# day
# 2017-01-01  32.0   6.0    Rain
# 2017-01-04  32.0   9.0   Sunny
# 2017-01-05  28.0   9.0    Snow
# 2017-01-06  28.0   7.0    Snow
# 2017-01-07  32.0   7.0    Rain
# 2017-01-08  32.0   7.0   Sunny
# 2017-01-09  32.0   7.0   Sunny
# 2017-01-10  34.0   8.0  Cloudy
# 2017-01-11  40.0  12.0   Sunny

# %%
new_df=df.fillna(method='bfill')
new_df
# Out:
#             temp  wind   event
# day
# 2017-01-01  32.0   6.0    Rain
# 2017-01-04  28.0   9.0   Sunny
# 2017-01-05  28.0   7.0    Snow
# 2017-01-06  32.0   7.0    Rain
# 2017-01-07  32.0   8.0    Rain
# 2017-01-08  34.0   8.0   Sunny
# 2017-01-09  34.0   8.0  Cloudy
# 2017-01-10  34.0   8.0  Cloudy
# 2017-01-11  40.0  12.0   Sunny

# %%
new_df=df.fillna(method='bfill',axis='columns')
new_df
# Out:
#              temp   wind   event
# day
# 2017-01-01     32      6    Rain
# 2017-01-04      9      9   Sunny
# 2017-01-05     28   Snow    Snow
# 2017-01-06      7      7     NaN
# 2017-01-07     32   Rain    Rain
# 2017-01-08  Sunny  Sunny   Sunny
# 2017-01-09    NaN    NaN     NaN
# 2017-01-10     34      8  Cloudy
# 2017-01-11     40     12   Sunny

# %%
new_df=df.interpolate()
new_df
# Out:
#                  temp   wind   event
# day
# 2017-01-01  32.000000   6.00    Rain
# 2017-01-04  30.000000   9.00   Sunny
# 2017-01-05  28.000000   8.00    Snow
# 2017-01-06  30.000000   7.00     NaN
# 2017-01-07  32.000000   7.25    Rain
# 2017-01-08  32.666667   7.50   Sunny
# 2017-01-09  33.333333   7.75     NaN
# 2017-01-10  34.000000   8.00  Cloudy
# 2017-01-11  40.000000  12.00   Sunny

# %%
new_df=df.dropna()
new_df
# Out:
#             temp  wind   event
# day
# 2017-01-01  32.0   6.0    Rain
# 2017-01-10  34.0   8.0  Cloudy
# 2017-01-11  40.0  12.0   Sunny

# %%
new_df=df.dropna(how='all')
new_df
# Out:
#             temp  wind   event
# day
# 2017-01-01  32.0   6.0    Rain
# 2017-01-04   NaN   9.0   Sunny
# 2017-01-05  28.0   NaN    Snow
# 2017-01-06   NaN   7.0     NaN
# 2017-01-07  32.0   NaN    Rain
# 2017-01-08   NaN   NaN   Sunny
# 2017-01-10  34.0   8.0  Cloudy
# 2017-01-11  40.0  12.0   Sunny

# %%
new_df=df.dropna(thresh=2)
new_df
# Out:
#             temp  wind   event
# day
# 2017-01-01  32.0   6.0    Rain
# 2017-01-04   NaN   9.0   Sunny
# 2017-01-05  28.0   NaN    Snow
# 2017-01-07  32.0   NaN    Rain
# 2017-01-10  34.0   8.0  Cloudy
# 2017-01-11  40.0  12.0   Sunny

# %%
df
# Out:
#          day  temp  wind   event
# 0 2017-01-01  32.0   6.0    Rain
# 1 2017-01-04   NaN   9.0   Sunny
# 2 2017-01-05  28.0   NaN    Snow
# 3 2017-01-06   NaN   7.0     NaN
# 4 2017-01-07  32.0   NaN    Rain
# 5 2017-01-08   NaN   NaN   Sunny
# 6 2017-01-09   NaN   NaN     NaN
# 7 2017-01-10  34.0   8.0  Cloudy
# 8 2017-01-11  40.0  12.0   Sunny

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\weather_data.csv',parse_dates=['day'])
df
# Out:
#          day  temp  wind   event
# 0 2017-01-01  32.0   6.0    Rain
# 1 2017-01-04   NaN   9.0   Sunny
# 2 2017-01-05  28.0   NaN    Snow
# 3 2017-01-06   NaN   7.0     NaN
# 4 2017-01-07  32.0   NaN    Rain
# 5 2017-01-08   NaN   NaN   Sunny
# 6 2017-01-09   NaN   NaN     NaN
# 7 2017-01-10  34.0   8.0  Cloudy
# 8 2017-01-11  40.0  12.0   Sunny

# %%
dt=pd.date_range('01-01-2017','01-11-2017')
idx=pd.DatetimeIndex(dt)
df=df.reindex(idx)
df
# Out:
#             temp  wind   event
# 2017-01-01  32.0   6.0    Rain
# 2017-01-02   NaN   NaN     NaN
# 2017-01-03   NaN   NaN     NaN
# 2017-01-04   NaN   9.0   Sunny
# 2017-01-05  28.0   NaN    Snow
# 2017-01-06   NaN   7.0     NaN
# 2017-01-07  32.0   NaN    Rain
# 2017-01-08   NaN   NaN   Sunny
# 2017-01-09   NaN   NaN     NaN
# 2017-01-10  34.0   8.0  Cloudy
# 2017-01-11  40.0  12.0   Sunny

# %%
df
# Out:
#             temp  wind   event
# 2017-01-01  32.0   6.0    Rain
# 2017-01-02   NaN   NaN     NaN
# 2017-01-03   NaN   NaN     NaN
# 2017-01-04   NaN   9.0   Sunny
# 2017-01-05  28.0   NaN    Snow
# 2017-01-06   NaN   7.0     NaN
# 2017-01-07  32.0   NaN    Rain
# 2017-01-08   NaN   NaN   Sunny
# 2017-01-09   NaN   NaN     NaN
# 2017-01-10  34.0   8.0  Cloudy
# 2017-01-11  40.0  12.0   Sunny

# %%
df.columns
# Out:
# Index(['temp', 'wind', 'event'], dtype='object')

# %%
df.set_index('temp',inplace=True)
df
# Out:
#        wind   event
# temp
#  32.0   6.0    Rain
# NaN     NaN     NaN
# NaN     NaN     NaN
# NaN     9.0   Sunny
#  28.0   NaN    Snow
# NaN     7.0     NaN
#  32.0   NaN    Rain
# NaN     NaN   Sunny
# NaN     NaN     NaN
#  34.0   8.0  Cloudy
#  40.0  12.0   Sunny

# %%
df.columns
# Out:
# Index(['wind', 'event'], dtype='object')

# %%
new_df=df.fillna(0)
new_df
# Out:
#        wind   event
# temp
#  32.0   6.0    Rain
# NaN     0.0       0
# NaN     0.0       0
# NaN     9.0   Sunny
#  28.0   0.0    Snow
# NaN     7.0       0
#  32.0   0.0    Rain
# NaN     0.0   Sunny
# NaN     0.0       0
#  34.0   8.0  Cloudy
#  40.0  12.0   Sunny

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\weather_data.csv',parse_dates=['day'])
df
# Out:
#          day  temp  wind   event
# 0 2017-01-01  32.0   6.0    Rain
# 1 2017-01-04   NaN   9.0   Sunny
# 2 2017-01-05  28.0   NaN    Snow
# 3 2017-01-06   NaN   7.0     NaN
# 4 2017-01-07  32.0   NaN    Rain
# 5 2017-01-08   NaN   NaN   Sunny
# 6 2017-01-09   NaN   NaN     NaN
# 7 2017-01-10  34.0   8.0  Cloudy
# 8 2017-01-11  40.0  12.0   Sunny

# %%
df
# Out:
#             temp  wind   event
# day
# 2017-01-01  32.0   6.0    Rain
# 2017-01-04   NaN   9.0   Sunny
# 2017-01-05  28.0   NaN    Snow
# 2017-01-06   NaN   7.0     NaN
# 2017-01-07  32.0   NaN    Rain
# 2017-01-08   NaN   NaN   Sunny
# 2017-01-09   NaN   NaN     NaN
# 2017-01-10  34.0   8.0  Cloudy
# 2017-01-11  40.0  12.0   Sunny

# %%
new_df=df.set_index('temp')
new_df
# Out:
#        wind   event
# temp
#  32.0   6.0    Rain
# NaN     9.0   Sunny
#  28.0   NaN    Snow
# NaN     7.0     NaN
#  32.0   NaN    Rain
# NaN     NaN   Sunny
# NaN     NaN     NaN
#  34.0   8.0  Cloudy
#  40.0  12.0   Sunny

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\stockdata.csv')
df
# Out:
#   tickers            eps  rev price         people
# 0   GOOGL          27.82   87   845     Larry Page
# 1     WMT           4.61  484    65           n.a.
# 2    MSFT             -1   85    64     Bill Gates
# 3     RIL  not available   50  1023  Mukesh Ambani
# 4    TATA            5.6   -1  n.a.     Ratan Tata

# %%
df.set_index('tickers')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3fd4b641a249> in <module>
# ----> 1 df.set_index('tickers')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
weather={
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017','1/6/2017'],
    'temp':[32,-9999,28,-9999,32,31,34],
    'wind':[6,7,-9999,7,-9999,2,5],
    'event':['Rain','Sunny','Snow','No Event','Rain','Sunny','No Event']
}
df=pd.DataFrame(weather)
df
# Out:
#         day  temp  wind     event
# 0  1/1/2017    32     6      Rain
# 1  1/2/2017 -9999     7     Sunny
# 2  1/3/2017    28 -9999      Snow
# 3  1/4/2017 -9999     7  No Event
# 4  1/5/2017    32 -9999      Rain
# 5  1/6/2017    31     2     Sunny
# 6  1/6/2017    34     5  No Event

# %%
import numpy as np

# %%
new_df=df.replace(-9999,np.NaN)
new_df
# Out:
#         day  temp  wind     event
# 0  1/1/2017  32.0   6.0      Rain
# 1  1/2/2017   NaN   7.0     Sunny
# 2  1/3/2017  28.0   NaN      Snow
# 3  1/4/2017   NaN   7.0  No Event
# 4  1/5/2017  32.0   NaN      Rain
# 5  1/6/2017  31.0   2.0     Sunny
# 6  1/6/2017  34.0   5.0  No Event

# %%
import pandas as pd
weather={
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017','1/6/2017'],
    'temp':[32,-9999,28,-9999,32,31,34],
    'wind':[6,7,-9999,7,-9999,2,5],
    'event':['Rain','Sunny','Snow','No Event','Rain','Sunny','No Event']
}
df=pd.DataFrame(weather)
df
# Out:
#         day  temp  wind     event
# 0  1/1/2017    32     6      Rain
# 1  1/2/2017 -9999     7     Sunny
# 2  1/3/2017    28 -9999      Snow
# 3  1/4/2017 -9999     7  No Event
# 4  1/5/2017    32 -9999      Rain
# 5  1/6/2017    31     2     Sunny
# 6  1/6/2017    34     5  No Event

# %%
new_df=df.replace(-9999,np.NaN)
new_df
# Out:
#         day  temp  wind     event
# 0  1/1/2017  32.0   6.0      Rain
# 1  1/2/2017   NaN   7.0     Sunny
# 2  1/3/2017  28.0   NaN      Snow
# 3  1/4/2017   NaN   7.0  No Event
# 4  1/5/2017  32.0   NaN      Rain
# 5  1/6/2017  31.0   2.0     Sunny
# 6  1/6/2017  34.0   5.0  No Event

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\we6replace.csv')
df
# Out:
#           day  temp  wind     event
# 0  01-01-2017    32     6      Rain
# 1  01-02-2017 -9999     7     Sunny
# 2  01-03-2017    28 -9999      Snow
# 3  01-04-2017 -9999     7  No Event
# 4  01-05-2017    32 -8888      Rain
# 5  01-06-2017    31     2     Sunny
# 6  01-06-2017    34     5  No Event

# %%
new_df=df.replace(-9999,np.NaN)
new_df
# Out:
#           day  temp    wind     event
# 0  01-01-2017  32.0     6.0      Rain
# 1  01-02-2017   NaN     7.0     Sunny
# 2  01-03-2017  28.0     NaN      Snow
# 3  01-04-2017   NaN     7.0  No Event
# 4  01-05-2017  32.0 -8888.0      Rain
# 5  01-06-2017  31.0     2.0     Sunny
# 6  01-06-2017  34.0     5.0  No Event

# %%
new_df=df.replace([-9999,-8888],np.NaN)
new_df
# Out:
#           day  temp  wind     event
# 0  01-01-2017  32.0   6.0      Rain
# 1  01-02-2017   NaN   7.0     Sunny
# 2  01-03-2017  28.0   NaN      Snow
# 3  01-04-2017   NaN   7.0  No Event
# 4  01-05-2017  32.0   NaN      Rain
# 5  01-06-2017  31.0   2.0     Sunny
# 6  01-06-2017  34.0   5.0  No Event

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\we6replace.csv')
df
# Out:
#           day  temp  wind  event
# 0  01-01-2017    32     6   Rain
# 1  01-02-2017 -9999     7  Sunny
# 2  01-03-2017    28 -9999   Snow
# 3  01-04-2017 -9999     7      0
# 4  01-05-2017    32 -9999   Rain
# 5  01-06-2017    31     2  Sunny
# 6  01-06-2017    34     5      0

# %%
df.columns
# Out:
# Index(['day', 'temp', 'wind', 'event'], dtype='object')

# %%
new_df=df.replace({
    'temp': -9999,
    'wind': -9999,
    'event':' 0'
},np.NaN)
new_df
# Out:
#           day  temp  wind  event
# 0  01-01-2017  32.0   6.0   Rain
# 1  01-02-2017   NaN   7.0  Sunny
# 2  01-03-2017  28.0   NaN   Snow
# 3  01-04-2017   NaN   7.0      0
# 4  01-05-2017  32.0   NaN   Rain
# 5  01-06-2017  31.0   2.0  Sunny
# 6  01-06-2017  34.0   5.0      0

# %%
weather={
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017','1/6/2017'],
    'temp':[32,-9999,28,-9999,32,31,34],
    'wind':[6,7,-9999,7,-9999,2,5],
    'event':['Rain','Sunny','Snow','No Event','Rain','Sunny','No Event']
}
df=pd.DataFrame(weather)
df
# Out:
#         day  temp  wind     event
# 0  1/1/2017    32     6      Rain
# 1  1/2/2017 -9999     7     Sunny
# 2  1/3/2017    28 -9999      Snow
# 3  1/4/2017 -9999     7  No Event
# 4  1/5/2017    32 -9999      Rain
# 5  1/6/2017    31     2     Sunny
# 6  1/6/2017    34     5  No Event

# %%
df.to_csv('C:\\MyData\\Python\\DataSet\\we6replace.csv',index=False)

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\we6replace.csv')
df
# Out:
#         day  temp  wind     event
# 0  1/1/2017    32     6      Rain
# 1  1/2/2017 -9999     7     Sunny
# 2  1/3/2017    28 -9999      Snow
# 3  1/4/2017 -9999     7  No Event
# 4  1/5/2017    32 -9999      Rain
# 5  1/6/2017    31     2     Sunny
# 6  1/6/2017    34     5  No Event

# %%
new_df=df.replace(-9999,np.NaN)
new_df
# Out:
#         day  temp  wind     event
# 0  1/1/2017  32.0   6.0      Rain
# 1  1/2/2017   NaN   7.0     Sunny
# 2  1/3/2017  28.0   NaN      Snow
# 3  1/4/2017   NaN   7.0  No Event
# 4  1/5/2017  32.0   NaN      Rain
# 5  1/6/2017  31.0   2.0     Sunny
# 6  1/6/2017  34.0   5.0  No Event

# %%
new_df=df.replace([-9999,'No Event'],np.NaN)
new_df
# Out:
#         day  temp  wind  event
# 0  1/1/2017  32.0   6.0   Rain
# 1  1/2/2017   NaN   7.0  Sunny
# 2  1/3/2017  28.0   NaN   Snow
# 3  1/4/2017   NaN   7.0    NaN
# 4  1/5/2017  32.0   NaN   Rain
# 5  1/6/2017  31.0   2.0  Sunny
# 6  1/6/2017  34.0   5.0    NaN

# %%
new_df=df.replace({
    -9999:np.NaN,
    'No Event':'Sunny'
})
new_df
# Out:
#         day  temp  wind  event
# 0  1/1/2017  32.0   6.0   Rain
# 1  1/2/2017   NaN   7.0  Sunny
# 2  1/3/2017  28.0   NaN   Snow
# 3  1/4/2017   NaN   7.0  Sunny
# 4  1/5/2017  32.0   NaN   Rain
# 5  1/6/2017  31.0   2.0  Sunny
# 6  1/6/2017  34.0   5.0  Sunny

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\we6replace.csv')
df
# Out:
#           day   temp   wind     event
# 0  01-01-2017    32F   6mph      Rain
# 1  01-02-2017  -9999      7     Sunny
# 2  01-03-2017     28  -9999      Snow
# 3  01-04-2017  -9999   7mph  No Event
# 4  01-05-2017    32C  -9999      Rain
# 5  01-06-2017     31      2     Sunny
# 6  01-06-2017     34      5  No Event

# %%
new_df=df.replace('[A-Za-z]','',regex=True)
new_df
# Out:
#           day   temp   wind event
# 0  01-01-2017     32      6
# 1  01-02-2017  -9999      7
# 2  01-03-2017     28  -9999
# 3  01-04-2017  -9999      7
# 4  01-05-2017     32  -9999
# 5  01-06-2017     31      2
# 6  01-06-2017     34      5

# %%
new_df=df.replace({
    'temp':'[A-Za-z]',
    'wind':'[A-Za-z]'
},'',regex=True)
new_df
# Out:
#           day   temp   wind     event
# 0  01-01-2017     32      6      Rain
# 1  01-02-2017  -9999      7     Sunny
# 2  01-03-2017     28  -9999      Snow
# 3  01-04-2017  -9999      7  No Event
# 4  01-05-2017     32  -9999      Rain
# 5  01-06-2017     31      2     Sunny
# 6  01-06-2017     34      5  No Event

# %%
df=pd.DataFrame({
    'score':['exceptional','average','good','poor','average','exceptional'],
    'student':['rob','maya','parth','tom','juli','erica']
})
df
# Out:
#          score student
# 0  exceptional     rob
# 1      average    maya
# 2         good   parth
# 3         poor     tom
# 4      average    juli
# 5  exceptional   erica

# %%
new_df=df.replace(['poor','average','good','exceptional'],[1,2,3,4])
new_df
# Out:
#    score student
# 0      4     rob
# 1      2    maya
# 2      3   parth
# 3      1     tom
# 4      2    juli
# 5      4   erica

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\weather_data_bycity.csv')
df
# Out:
#            day     city  temp  wind   event
# 0   01-01-2017  newyork    32     6    Rain
# 1   01-02-2017  newyork    36     7   Sunny
# 2   01-03-2017  newyork    28    12    Snow
# 3   01-04-2017  newyork    33     7   Sunny
# 4   01-01-2017   mumbai    90     5   Sunny
# 5   01-02-2017   mumbai    85    12    Snow
# 6   01-03-2017   mumbai    87    15     Fog
# 7   01-04-2017   mumbai    92     5    Rain
# 8   01-01-2017    paris    45    20   Sunny
# 9   01-02-2017    paris    50    13  Cloudy
# 10  01-03-2017    paris    54     8  Cloudy
# 11  01-04-2017    paris    42    10  Cloudy

# %%
g=df.groupby('city')
g

# %%
for city,city_df in g:
    print(city),
    print(city_df)
# Out:
# mumbai
#           day    city  temp  wind  event
# 4  01-01-2017  mumbai    90     5  Sunny
# 5  01-02-2017  mumbai    85    12   Snow
# 6  01-03-2017  mumbai    87    15    Fog
# 7  01-04-2017  mumbai    92     5   Rain
# newyork
#           day     city  temp  wind  event
# 0  01-01-2017  newyork    32     6   Rain
# 1  01-02-2017  newyork    36     7  Sunny
# 2  01-03-2017  newyork    28    12   Snow
# 3  01-04-2017  newyork    33     7  Sunny
# paris
#            day   city  temp  wind   event
# 8   01-01-2017  paris    45    20   Sunny
# 9   01-02-2017  paris    50    13  Cloudy
# 10  01-03-2017  paris    54     8  Cloudy
# 11  01-04-2017  paris    42    10  Cloudy

# %%
g.get_group('mumbai')
# Out:
#           day    city  temp  wind  event
# 4  01-01-2017  mumbai    90     5  Sunny
# 5  01-02-2017  mumbai    85    12   Snow
# 6  01-03-2017  mumbai    87    15    Fog
# 7  01-04-2017  mumbai    92     5   Rain

# %%
g.describe()
# Out:
#          temp                                                   wind         \
#         count   mean       std   min    25%   50%    75%   max count   mean
# city
# mumbai    4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0   4.0   9.25
# newyork   4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0   4.0   8.00
# paris     4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0   4.0  12.75
#
#
#               std  min   25%   50%    75%   max
# city
# mumbai   5.057997  5.0  5.00   8.5  12.75  15.0
# newyork  2.708013  6.0  6.75   7.0   8.25  12.0
# paris    5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai     AxesSubplot(0.125,0.125;0.775x0.755)
# newyork    AxesSubplot(0.125,0.125;0.775x0.755)
# paris      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
india_weather=pd.DataFrame({
    'city':['mumbai','delhi','banglore'],
    'temp':[32,45,30],
    'humd':[80,60,70]
})
india_weather
# Out:
#        city  temp  humd
# 0    mumbai    32    80
# 1     delhi    45    60
# 2  banglore    30    70

# %%
us_weather=pd.DataFrame({
    'city':['new york','chicago','orlando'],
    'temp':[21,14,35],
    'humd':[68,65,75]
})
us_weather
# Out:
#        city  temp  humd
# 0  new york    21    68
# 1   chicago    14    65
# 2   orlando    35    75

# %%
df=pd.concat([india_weather,us_weather])
df
# Out:
#        city  temp  humd
# 0    mumbai    32    80
# 1     delhi    45    60
# 2  banglore    30    70
# 0  new york    21    68
# 1   chicago    14    65
# 2   orlando    35    75

# %%
df=pd.concat([india_weather,us_weather],ignore_index=True)
df
# Out:
#        city  temp  humd
# 0    mumbai    32    80
# 1     delhi    45    60
# 2  banglore    30    70
# 3  new york    21    68
# 4   chicago    14    65
# 5   orlando    35    75

# %%
df=pd.concat([india_weather,us_weather],keys=['india','us'])
df
# Out:
#              city  temp  humd
# india 0    mumbai    32    80
#       1     delhi    45    60
#       2  banglore    30    70
# us    0  new york    21    68
#       1   chicago    14    65
#       2   orlando    35    75

# %%
df.loc['us']
# Out:
#        city  temp  humd
# 0  new york    21    68
# 1   chicago    14    65
# 2   orlando    35    75

# %%
india_temp=pd.DataFrame({
    'city':['mumbai','delhi','banglore'],
    'temp':[32,45,30]
},index=[0,1,2])
india_temp
# Out:
#        city  temp
# 0    mumbai    32
# 1     delhi    45
# 2  banglore    30

# %%
windspeed=pd.DataFrame({
    'city':['delhi','mumbai'],
    'temp':[7,12]
},index=[1,0])
windspeed
# Out:
#      city  temp
# 1   delhi     7
# 0  mumbai    12

# %%
df=pd.concat([india_temp,windspeed],axis=1)
df
# Out:
#        city  temp    city  temp
# 0    mumbai    32  mumbai  12.0
# 1     delhi    45   delhi   7.0
# 2  banglore    30     NaN   NaN

# %%
india_temp=pd.DataFrame({
    'city':['mumbai','delhi','banglore'],
    'temp':[32,45,30]
},index=[0,1,2])
india_temp
# Out:
#        city  temp
# 0    mumbai    32
# 1     delhi    45
# 2  banglore    30

# %%
s=pd.Series(['Humid','Dry','Rain'],name='event')
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
pd.concat([india_temp,s],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c7b2429f6149> in <module>
# ----> 1 pd.concat([india_temp,s],axis=1)
#
# NameError: name 'india_temp' is not defined

# %%
df1=pd.DataFrame({
    'city':['new york','chicago','orlando','baltimore'],
    'temp':[21,14,35,38],
    'humd':[65,68,71,75]
    })
df1
# Out:
#         city  temp  humd
# 0   new york    21    65
# 1    chicago    14    68
# 2    orlando    35    71
# 3  baltimore    38    75

# %%
df2=pd.DataFrame({
    'city':['chicago','new york','san francisco'],
    'temp':[21,14,35],
    'humd':[65,68,71]
})
df2
# Out:
#             city  temp  humd
# 0        chicago    21    65
# 1       new york    14    68
# 2  san francisco    35    71

# %%
df3=pd.merge(df1,df2,on='city',suffixes=('_left','_right'))
df3
# Out:
#        city  temp_left  humd_left  temp_right  humd_right
# 0  new york         21         65          14          68
# 1   chicago         14         68          21          65

# %%
weather=pd.DataFrame({
    'date':['5-01-2017','5-02-2017','5-03-2017','5-01-2017','5-02-2017','5-03-2017','5-01-2017','5-02-2017','5-03-2017'],
    'city':['new york','new york','new york','mumbai','mumbai','mumbai','beijing','beijing','beijing'],
    'temp':[65,66,68,75,78,82,80,77,79],
    'humd':[56,58,60,80,83,85,26,30,35]
})
weather
# Out:
#         date      city  temp  humd
# 0  5-01-2017  new york    65    56
# 1  5-02-2017  new york    66    58
# 2  5-03-2017  new york    68    60
# 3  5-01-2017    mumbai    75    80
# 4  5-02-2017    mumbai    78    83
# 5  5-03-2017    mumbai    82    85
# 6  5-01-2017   beijing    80    26
# 7  5-02-2017   beijing    77    30
# 8  5-03-2017   beijing    79    35

# %%
type(weather.date[0])
# Out:
# str

# %%
weather.to_csv('C:\\MyData\\Python\\DataSet\\weather1.csv',index=False)

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\weather1.csv')
df
# Out:
#         date      city  temp  humd
# 0  5-01-2017  new york    65    56
# 1  5-02-2017  new york    66    58
# 2  5-03-2017  new york    68    60
# 3  5-01-2017    mumbai    75    80
# 4  5-02-2017    mumbai    78    83
# 5  5-03-2017    mumbai    82    85
# 6  5-01-2017   beijing    80    26
# 7  5-02-2017   beijing    77    30
# 8  5-03-2017   beijing    79    35

# %%
type(df.date[0])
# Out:
# str

# %%
df['date']=pd.to_datetime(df['date'])

# %%
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.columns
# Out:
# Index(['date', 'city', 'temp', 'humd'], dtype='object')

# %%
df.pivot(index='date',columns='city',values='humd')
# Out:
# city        beijing  mumbai  new york
# date
# 2017-05-01       26      80        56
# 2017-05-02       30      83        58
# 2017-05-03       35      85        60

# %%
df=pd.DataFrame({
    'date':['5-01-2017','5-01-2017','5-02-2017','5-02-2017','5-01-2017','5-01-2017','5-02-2017','5-02-2017'],
    'city':['new york','new york','new york','new york','mumbai','mumbai','mumbai','mumbai'],
    'temp':[65,61,70,72,75,78,82,80],
    'humd':[55,54,60,62,80,83,85,26]
})
df
# Out:
#         date      city  temp  humd
# 0  5-01-2017  new york    65    55
# 1  5-01-2017  new york    61    54
# 2  5-02-2017  new york    70    60
# 3  5-02-2017  new york    72    62
# 4  5-01-2017    mumbai    75    80
# 5  5-01-2017    mumbai    78    83
# 6  5-02-2017    mumbai    82    85
# 7  5-02-2017    mumbai    80    26

# %%
df.to_csv('C:\\MyData\\Python\\DataSet\\weather2.csv',index=False)

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\weather2.csv',parse_dates=['date'])
df
# Out:
#         date      city  temp  humd
# 0 2017-05-01  new york    65    55
# 1 2017-05-01  new york    61    54
# 2 2017-05-02  new york    70    60
# 3 2017-05-02  new york    72    62
# 4 2017-05-01    mumbai    75    80
# 5 2017-05-01    mumbai    78    83
# 6 2017-05-02    mumbai    82    85
# 7 2017-05-02    mumbai    80    26

# %%
df.pivot_table(index='city',columns='date',margins=True)
# Out:
#                         humd                                            temp  \
# date     2017-05-01 00:00:00 2017-05-02 00:00:00     All 2017-05-01 00:00:00
# city
# mumbai                  81.5               55.50  68.500               76.50
# new york                54.5               61.00  57.750               63.00
# All                     68.0               58.25  63.125               69.75
#
#
# date     2017-05-02 00:00:00     All
# city
# mumbai                  81.0  78.750
# new york                71.0  67.000
# All                     76.0  72.875

# %%
df=pd.DataFrame({
    'date':['5-01-2017','5-02-2017','5-03-2017','12-01-2017','12-02-2017','12-03-2017'],
    'city':['new york','new york','new york','new york','new york','new york'],
    'temp':[65,61,70,30,28,25],
    'humd':[56,54,60,50,52,51]
})
df
# Out:
#          date      city  temp  humd
# 0   5-01-2017  new york    65    56
# 1   5-02-2017  new york    61    54
# 2   5-03-2017  new york    70    60
# 3  12-01-2017  new york    30    50
# 4  12-02-2017  new york    28    52
# 5  12-03-2017  new york    25    51

# %%
df.to_csv('C:\\MyData\\Python\\DataSet\\weather3.csv',index=False)

# %%
df=pd.read_csv('C:\\MyData\\Python\\DataSet\\weather3.csv')
df
# Out:
#          date      city  temp  humd
# 0   5-01-2017  new york    65    56
# 1   5-02-2017  new york    61    54
# 2   5-03-2017  new york    70    60
# 3  12-01-2017  new york    30    50
# 4  12-02-2017  new york    28    52
# 5  12-03-2017  new york    25    51

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df
# Out:
#         date      city  temp  humd
# 0 2017-05-01  new york    65    56
# 1 2017-05-02  new york    61    54
# 2 2017-05-03  new york    70    60
# 3 2017-12-01  new york    30    50
# 4 2017-12-02  new york    28    52
# 5 2017-12-03  new york    25    51

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#                  humd       temp
# city         new york   new york
# date
# 2017-05-31  56.666667  65.333333
# 2017-12-31  51.000000  27.666667

# %%
df=pd.DataFrame({
    'day':['Monday','Tuesday','Wedensday','Thursday','Friday','Saturday','Sunday'],
    'chicago':[32,30,28,22,30,20,25],
    'chenai':[75,77,75,82,83,81,77],
    'berlin':[41,43,45,38,30,45,47]
})
df
# Out:
#          day  chicago  chenai  berlin
# 0     Monday       32      75      41
# 1    Tuesday       30      77      43
# 2  Wedensday       28      75      45
# 3   Thursday       22      82      38
# 4     Friday       30      83      30
# 5   Saturday       20      81      45
# 6     Sunday       25      77      47

# %%
df.to_csv('C:\\MyData\\Python\\DataSet\\weather4.csv',index=False)

# %%
df1=pd.melt(df,id_vars=['day'])
df1
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wedensday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday   chenai     75
# 8     Tuesday   chenai     77
# 9   Wedensday   chenai     75
# 10   Thursday   chenai     82
# 11     Friday   chenai     83
# 12   Saturday   chenai     81
# 13     Sunday   chenai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wedensday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
df1=pd.melt(df,id_vars=['day'])
df1[df1['variable']=='chicago']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ea19d5967364> in <module>
# ----> 1 df1=pd.melt(df,id_vars=['day'])
#       2 df1[df1['variable']=='chicago']
#
# NameError: name 'df' is not defined

# %%
df=pd.read_excel('C:\\MyData\\Python\\DataSet\\survey.xlsx')
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima        Bang  Female   31       Left
# 5    Kadir        Bang    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df.Sex,df.Handedness,margins=True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12
