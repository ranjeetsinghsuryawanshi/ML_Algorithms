# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
plt.rcParams['figure.figsize']=(20.0,10.0)
df=pd.read_csv('C:\\MyData\\Python\\Pra\DataSet\\headbrain.csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
x=df['Head Size(cm^3)'].values
y=df['Brain Weight(grams)'].values

# %%
xMean=np.mean(x)
yMean=np.mean(y)

m=len(x)

numerator=0
denometor=0
for i in range(m):
    numerator+=(x[i]-xMean)*(y[i]-yMean)
    denometor+=(x[i]-xMean)**2
b1=numerator/denometor
b0=yMean-(b1*xMean)
print(b1,b0)
# Out:
# 0.26342933948939956 325.573421049442

# %%
max_x=np.max(x)+100
min_x=np.min(x)-100
x=np.linspace(min_x,max_x,1000)
y=b0 + b1 * x
plt.plot(x,y,color='#58b970',label='Regression Line')
plt.scatter(x,y,c='#ef5423',label='Scattered Plot')
plt.xlabel('Head Size')
plt.ylabel('Brain Weight')
plt.legend()
plt.show()

# %%
ss_t=0
ss_r=0
for i in range(m):
    y_pred=b0 + b1 * x[i]
    ss_t+=(y[i]-yMean)**2
    ss_r+=(y[i]-y_pred)**2
    r2=1-(ss_r/ss_t)
print(r2)
# Out:
# 1.0

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
x=x.reshape((m,1))
reg=LinearRegression()
reg=reg.fit(x,y)
y_pred=reg.predict(x)
r2_score=reg.score(x,y)
print(r2_score)
# Out:
# 1.0

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.DataFrame({
    'time':[1,2,3,4,5],
    'activity':[96,84,70,58,52]
})
df
# Out:
#    time  activity
# 0     1        96
# 1     2        84
# 2     3        70
# 3     4        58
# 4     5        52

# %%
regr=linear_model.LinearRegression()
regr.fit(df[['activity']],df.time)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
regr.predict([[80]])
# Out:
# array([2.30909091])

# %%
df=pd.DataFrame({
    'stretching':[0,30,10,15,5,25,35,40],
    'injuries':[4,1,2,2,3,1,0,1]
})
df
# Out:
#    stretching  injuries
# 0           0         4
# 1          30         1
# 2          10         2
# 3          15         2
# 4           5         3
# 5          25         1
# 6          35         0
# 7          40         1

# %%
reger=linear_model.LinearRegression()
reger.fit(df[['stretching']],df.injuries)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reger.predict([[1]])
# Out:
# array([3.27])

# %%
reger.predict([[30]])
# Out:
# array([0.95])

# %%
df=pd.DataFrame({
    'x':[2005,2006,2007,2008,2009],
    'y':[12,19,29,37,45]
})
df
# Out:
#       x   y
# 0  2005  12
# 1  2006  19
# 2  2007  29
# 3  2008  37
# 4  2009  45

# %%
reger=linear_model.LinearRegression()
reger.fit(df[['x']],df.y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reger.predict([[2012]])
# Out:
# array([70.4])

# %%
df=pd.DataFrame({
    'Age':[17.5,22,29.5,44.5,64.5,80],
    'DriverDeaths':[38,36,24,20,18,28]
})
df
# Out:
#     Age  DriverDeaths
# 0  17.5            38
# 1  22.0            36
# 2  29.5            24
# 3  44.5            20
# 4  64.5            18
# 5  80.0            28

# %%
reger=linear_model.LinearRegression()
reger.fit(df[['Age']],df.DriverDeaths)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reger.predict([[40]])
# Out:
# array([27.90880807])

# %%
reger.predict([[60]])
# Out:
# array([24.07230984])
